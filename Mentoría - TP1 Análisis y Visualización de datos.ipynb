# %% [markdown]
# <a href="https://colab.research.google.com/github/ivanafeldfeber/diplo-datos/blob/main/Mentor%C3%ADa%20-%20TP1%20An%C3%A1lisis%20y%20Visualizaci%C3%B3n%20de%20datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mentoría

# %% [markdown]
# ## Análisis de datos sobre la violencia contra la mujer.
#
# * Tamara Maggioni
# * Susana Araujo
# * Ivana Feldfeber

# %% [markdown]
# ### Introducción

# %% [markdown]
# Para la mentoría trabajaremos con la **Macroencuesta de Violencia contra la Mujer 2019**, encuesta que se realiza en España sobre las violencias de género por la Delegación del Gobierno contra la Violencia de Género. Su principal objetivo es conocer el porcentaje de mujeres de 16 o más años residentes en España que han sufrido o que sufren actualmente algún tipo de violencia por el hecho de ser mujeres. De forma más específica, los principales objetivos de la macroencuesta son:
#
# 1) Estimar la prevalencia de la violencia contra la mujer en España, tanto la que se produce en el ámbito de la pareja actual o de parejas pasadas como la sufrida por las mujeres fuera del ámbito de la pareja, distinguiendo entre violencia física, sexual, psicológica y económica en el caso de la violencia en la pareja, y entre violencia física y sexual en el caso de la violencia ejercida por terceras personas. También se investiga el acoso sexual y el stalking.
#
# 2) Conocer los tipos de agresores más frecuentes, obtener información sobre la denuncia, la búsqueda de ayuda formal e informal, la satisfacción con la ayuda recibida, recabar información relacionada con hijos e hijas de las víctimas, especialmente los menores, en relación a su presencia durante los episodios de violencia, y conocer las consecuencias de la violencia sobre la salud física y mental de las mujeres afectadas.
#
# Esta macroencuesta se ha realizado a una muestra representativa de 9.568 mujeres en España.
#
# Los tipos de violencia de género medidos son:
#
# Violencia de la pareja actual y violencia de parejas pasadas
# * Física
# * Sexual
# * Psicológica: comportamientos de control y violencia emocional
# * Económica
#
# Violencia fuera de la pareja
# * Física
# * Sexual
#
# Acoso sexual
#
# Acoso reiterado (stalking)

# %% [markdown]
# ###El cuestionario

# %% [markdown]
# La Macroencuesta es muy exhaustiva, ya que diferencia entre relaciones actuales, relaciones con exparejas y violencias o acoso recibido por personas que no son pareja. A su vez diferencia sobre violencias actuales, con violencias sucedidas el último año y los últimos 4 años.
#
# Realiza hincapié en los y las menores de edad, para comprender si tambien fueron víctimas o se vieron afectados por las situaciones de violencia.
#
# El cuestionario puede verse en este link:
# https://drive.google.com/file/d/1PkKVaE20a8cTCdVJ4QDz_tWEERgBu2UB/view?usp=sharing
#
# Cuenta con 1121 preguntas, algunas de ellas tienen saltos en función de la respuesta de la persona entrevistada, a su vez cada pregunta tiene un código específico que luego será el nombre de las variables en el set de datos.
#
# En este link están los códigos de las preguntas así como sus posibles respuestas:
#
# https://drive.google.com/file/d/164Pvkly8ysFdwENgPmEURBxyXLbYuoN_/view?usp=sharing
#
# Cabe aclarar que esta encuesta no tiene ningún tipo de pregunta abierta, son preguntas cerradas con respuestas limitadas y estandarizadas para que sea más fácil su análisis.

# %% [markdown]
# ###El set de datos

# %% [markdown]
# El set de datos cuenta con 9568 filas, número que coincide con la cantidad de mujeres entrevistadas. A su vez cuenta con 1121 columnas que corresponden a las preguntas de la encuesta.
#
# La gran mayoría de las variables son categóricas, es decir que toman valores limitados y fijos, ya que como vimos anteriormente, las respuestas están estandarizadas.
#
# Hay pocas variables numéricas, la mayoría son strings, ya que para no dejar opción libre, se decidió que muchos valores numéricos se transformen en rangos, por ejemplo salario "de 0 a 500 euros", "de 501 euros a 900", etc
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Aquí podemos ver una pequeña parte del dataset, vemos que la mayoría de los tipos de datos son objetos de python que contienen strings.

# %% [markdown]
# ###Columnas del set de datos

# %% [markdown]
# Para realizar nuestro análisis decidimos reducir la cantidad de variables, enfocándonos exclusivamente en aquellas que estén vinculadas con la **violencia económica**. Comenzamos eligiendo manualmente aquellas variables que consideramos relevantes para el análisis, hicimos una pequeña lista y las renombramos para que sean explicativas.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Identificamos que las variables M1P1 estaban relacionadas con la violencia económica:
#
# **M1P1_08** Se niega o se ha negado a darle dinero para los gastos del hogar cuando la pareja tiene/tenía dinero para otras cosas
#
# **M1P1_09** Le impide o ha impedido tomar decisiones relacionadas con la economía familiar y/o realizar las compras de forma independiente
#
# **M1P1_10** No le deja o no le ha dejado trabajar o estudiar fuera del hogar
#
# **M1P1_11** Usa o ha usado su dinero o su tarjeta de crédito o pide préstamos a su nombre sin su consentimiento
#
# Las posibles respuestas a estas preguntas son:
#
# 1.- Frecuentemente
#
# 2.- Algunas veces
#
# 3.- Nunca
#
# 9.- N.C. (No Corresponde)
#
# 0.- N.P. (No Pertenece)

# %% [markdown]
# ###Análisis de variables demográficas

# %% [markdown]
# Dentro de toda la muestra decidimos enfocar el análisis en aquellas mujeres que estan en pareja actualmente. Sin embargo quisimos comparar las edades del total de la muestra y de nuestro recorte para ver si había diferencias significativas. Encontramos que la población más joven (entre 16 y 19 años) no está en pareja actualmente.

# %% [markdown]
# ####Edad de toda la muestra

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ####Edad de las mujeres en pareja

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Dentro de las edades podemos ver que todas son razonables y que coinciden con la pirámide de población de 2020 de España. Con lo que respecta a la edad, la muestra de mujeres es representativa de la población
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###Cruce de variables demográficas

# %% [markdown]
# ####Edad de las mujeres y fuente de ingreso principal del hogar

# %% [markdown]
# Para comprender mejor la fuente de ingreso de nuestra población, realizamos el siguiente boxplot para poder comprender mejor la vinculación entre la edad de las mujeres encuestadas y su fuente de ingresos.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Hay cuatro ingresos posibles:
#
# * Ingresos que vienen de parte de otra persona ("Otra persona")
#
# * Ingresos que vienen de la persona entrevistada ("La persona entrevistada")
#
# * Ingresos que son mitad de la persona entrevistada, mitad de otros ("La mitad la entrevistada")
#
# * No Corresponde
#
#
# Podemos ver que en general las personas más jóvenes no poseen ingresos propios ni de otras personas, que en general las personas con ingresos propios están en el rango de edad de 40 a 70 años y que la edad promedio baja cuando los ingresos provienen de otra persona.
#
# A partir de la siguiente tabla podemos ver que parece haber ocasiones donde la persona entrevistada, que tiene 16 años, es la persona que aporta el ingreso principal al hogar. También parece que hay casos en los cuales la persona tiene 16 años, pero aporta de manera casi igual que otra de las personas. Si bien esto es poco probable no califica como outlier ya que puede suceder.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ####Edad de las mujeres entrevistadas y nivel máximo de estudios

# %% [markdown]
# Para comprender mejor la vinculación entre la edad de las mujeres y su nivel de estudios realizamos el siguiente boxplot:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Algo que llama la atención es la caja vinculada al nivel "Sin estudios" o "Solo Primario", cuya media corresponde a mujeres adultas mayores. Si bien esto es llamativo, a su vez puede justificarse ya que la masividad de las mujeres en la educación es un movimiento que surge hace no tanto tiempo, hace algunas décadas atrás las mujeres eran criadas para casarse, tener hijos y ser amas de casa y la posibilidad de estudiar estaba reservada para los varones de la familia y algunas mujeres como exepción. Por lo tanto muchas adultas mayores no poseen estudios o comienzan a estudiar de adultas ya que antes no tuvieron esa oportunidad.

# %% [markdown]
# ####Edad de las mujeres entrevistadas, nivel máximo de estudios cuando el ingreso principal depende de ella

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Para este caso, donde la persona es la fuente del ingreso principal, la media de la edad de las personas sin estudios es menor, también la media de las personas que solo tienen de estudio la primaria.

# %% [markdown]
# Algo que nos llamó la atención es que para aquellas personas que son el ingreso principal, la mayoría tienen como opción en los estudios máximos, 'N.C.', que significa 'No Corresponde'. Así que decidimos indagar sobre las profesiones de "N.C."

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# El listado completo de profesiones es:
#
# 1.- Directoras y gerentes
#
# 2.- Técnicas y profesionales científicas e intelectuales
#
# 3.- Técnicas; profesionales de apoyo
#
# 4.- Empleadas contables, administrativas y otros empleadas de
# oficina
#
# 5.- Trabajadoras de los servicios de restauración, personales,
# protección y vendedoras
#
# 6.- Trabajadoras cualificadas en el sector agrícola, ganadero,
# forestal y pesquero
#
# 7.- Artesanas y trabajadoras cuali. de ind. manufactureras y
# construcción, no operadoras instalaciones y maquinaria
#
# 8.- Operadoras de instalaciones y maquinaria, y montadoras
#
# 9.- Ocupaciones elementales
#
# 10.- Ocupaciones militares
#
# 94.- Sin ocupación/vive de las rentas
#
# Si bien entendemos la necesidad de las respuestas cerradas, con éstas se pierde información y por ejemplo en este caso es difícil comprender porqué muchas mujeres eligieron la categoría "No Corresponde" cuando les preguntaron sobre sus estudios máximos.

# %% [markdown]
# ###Trabajo sobre las variables de violencia económica

# %% [markdown]
# ####Limpieza de datos
#
# Como nuestras variables tenían muchas respuestas posibles, decidimos comenzar a agrupar y renombrar los valores posibles de las mismas, para poder comprender mejor los grupos en función de ingresos, situación laboral y violencias y hacer el análisis de correlaciones correspondiente.
#
# Para esto renombramos aquellas personas que trabajan actualmente ya que esta variable tenía demasiadas respuestas posibles, por lo tanto decidimos separar entre "Trabaja" y "No_trabaja"
#
# Es necesario aclarar que este grupo está a favor con las corrientes teóricas de pensamiento feminista que reivindican que el trabajo doméstico no remunerado *es trabajo* pero para los fines de este análisis, queríamos detectar la violencia económica separando a quienes ganan dinero por su trabajo, de quienes no lo hacen, por lo tanto tomamos estas decisiones de etiquetado.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# El mismo trabajo realizamos para la variable "Ingresos propios" y separamos quienes tenían ingresos propios de quienes no los tenían
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ####Encodings

# %% [markdown]
# Otra tarea que realizamos fue pasar las variables categóricas a numéricas para poder hacer el análisis de correlación. Decidimos hacerlo manualmente, para poder decidir qué número se le asigna a cada valor. En un futuro utilizaremos OneHotEncoder para realizar los encodings sin jerarquías ni pesos en variables categóricas.

# %% [markdown]
# ####Datos faltantes
# Encontramos que había nulls en la columna de "fuente de ingresos alternativos", por lo tanto asumimos que si no había respuesta en esa columna es porque la persona no tenía una fuente de ingresos alternativos y decidimos imputar con "No" los casos de nulls.
#
# Más allá de esa columna, no encontramos otros datos faltantes dentro de las variables que nos propusimos analizar para este primer entregable.

# %% [markdown]
# ####Análisis sobre la fuente de ingresos

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# En esta tabla de contingencia, vemos que cerca de un 70% tiene una fuente principal de ingresos propios, mientras que un 30% no. Sin embargo, solamente el 50% trabaja y otro 50% no trabaja. Es decir, que el trabajo es una fuente muy importante, pero no la única, de los ingresos personales. Otras fuentes (ese 20% restante) está compuesto por: pensiones, jubilaciones, becas, subsidios o ahorros y rentas a la propiedad.
# En este caso podríamos decir que fuente de ingresos y situación laboral no  están dando exactamente la misma información, por lo que no podríamos descartar ninguna de estas preguntas. Sí, por el contrario, podríamos reducir la cantidad de respuestas posibles.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# En cuanto a los ingresos alternativos, solo 8% afirma poseerlos. De ese total, un 7% cuenta, además, con ingresos propios como fuente principal de dinero. Sólo un 1% de las personas que no cuentan con ingresos propios como fuente principal, cuentan únicamente con ingresos alternativos.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Acá podemos ver las dos variables de ingresos (principal y alternativa) en relación a la tenencia de un trabajo. Nuevamente, la mitad de las personas encuestadas trabaja y la otra mitad no. Las personas con ingresos principales y alternativos solo suma un 7%. En cambio, un 60% cuenta únicamente con ingresos principales. Un 9% cuenta únicamente con ingresos alternativos (6% no trabaja y 3% sí). Las personas que no cuentan ni con ingresos principales ni con alternativos, ascienden a cerca de 30%.

# %% [markdown]
# ###Correlaciones

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Aquí podemos observar que hay una gran correlación cuando la persona trabaja y tiene una fuentes de ingreso principal.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Otra correlación que podemos encontrar con respecto a las violencias económicas está vinculada a las variables:
#
# - Se niega o se ha negado a darle dinero para los gastos del hogar cuando la pareja tiene/tenía dinero para otras cosas
#
# - Trata o ha tratado de evitar que Ud. se relacione con su familia directa o parientes

# %% [markdown]
# ####Conclusiones parciales

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Como podemos ver en la tabla cruzada de arriba, el 98% de nuestro universo muestral nunca ha recibido lo que consideramos violencia economica, y puede que esto tenga que ver con que casi el 70% cuenta con ingresos personales (principales, alternativos o ambos): un 50% provenientes de una fuente de trabajo y un 20% restante proveniente de pensiones, jubilación, subsidios, becas, rentas.
#
# Si bien poseíamos varias hipótesis sobre la vinculación entre desempleo o falta de dinero y violencia económica por parte de la pareja, sería poco profesional sacar conclusiones sobre una muestra tan pequeña de gente sí sufre violencia económica.

# %% [markdown]
# #Anexo del código utilizado
#
# En la siguiente notebook, realizaremos la carga del dataset que utilizarán para el práctico de la materia. Para ello, comenzaremos con las importaciones pertinentes.
# Posteriormente, se detallarán las consignas a seguir para la elaboración del informe.

# %%
# importación de las librerías necesarias
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
pd.set_option('display.max_columns', 150)
pd.set_option('display.max_rows', 150)
pd.set_option('max_colwidth', 151)
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Revisión general de los datos

# %%
# carga del dataset
url = 'https://drive.google.com/file/d/1CPlW53w9zNWWNyF_7xLDsPysKSDNVAvo/view?usp=sharing'
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
dataset = pd.read_csv(path, dtype=str, na_values=[" "])

# %% [markdown]
# ### Dataset

# %%
# aquí simplemente visualizamos algunas filas y columnas de nuestro dataset
dataset.sample(3)
# Out:
#      ESTUDIO REGISTRO  CUES    FECHAINI   HORAINI    FECHAFIN   HORAFIN  \
# 1365    3235    24729  1384  20/09/2019  10:38:17  20/09/2019  10:53:38
# 8799    3235   166585  8915  17/11/2019  15:15:37  17/11/2019  15:27:08
# 2619    3235    46712  2654  14/10/2019  12:58:55  14/10/2019  13:18:16
#
#      DURACION                   CCAA       PROV  \
# 1365      920                 Aragón     Huesca
# 8799      690  Madrid (Comunidad de)     Madrid
# 2619     1160               Cataluña  Barcelona
#
#                                                     MUN        DISTR  \
# 1365                                             Huesca  Anonimizado
# 8799  Mun.<=100.000 hab. no capitales de CA o provincia  Anonimizado
# 2619  Mun.<=100.000 hab. no capitales de CA o provincia  Anonimizado
#
#           SECCION               CAPITAL                       TAMUNI  \
# 1365  Anonimizado  Capital de provincia  50.001 a 100.000 habitantes
# 8799  Anonimizado      Otros municipios   10.001 a 50.000 habitantes
# 2619  Anonimizado      Otros municipios  50.001 a 100.000 habitantes
#
#      COORDINADOR       ENTREV                                         M0P0  \
# 1365        C340  Anonimizado                  Parada y ha trabajado antes
# 8799       C1707  Anonimizado  Pensionista (anteriormente no ha trabajado)
# 2619        C714  Anonimizado              Trabajo doméstico no remunerado
#
#                              M0P1 M0P2 M0P3 M0P4 M0P4A M0P4B M0P4C M0P5 M0P5A  \
# 1365  Todos o casi todos los días   Sí   Sí   No  N.P.  N.P.  N.P.   No  N.P.
# 8799  Todos o casi todos los días   Sí   Sí   Sí    No  N.P.  N.P.   No  N.P.
# 2619          Varias veces al mes   Sí   Sí   Sí    No  N.P.  N.P.   No  N.P.
#
#            M0P6    M0P7_1 M0P7_2    M0P7_3 M0P7_4 M0P7_5 M0P7_6 M0P7_7  \
# 1365  Muy bueno       NaN    NaN       NaN    NaN    NaN    NaN    NaN
# 8799      Bueno  Menciona    NaN       NaN    NaN    NaN    NaN    NaN
# 2619       Malo  Menciona    NaN  Menciona    NaN    NaN    NaN    NaN
#
#         M0P7_8 M0P7_9 M0P8                              M0P9 M0P10_1 M0P10_2  \
# 1365  Menciona    NaN   No                                No      No      Sí
# 8799       NaN    NaN   No                                No      Sí      Sí
# 2619       NaN    NaN   Sí  Sí, pero no le limita gravemente      Sí      Sí
#
#      M0P10_3 M0P10_4 M0P10_5   M0P11_1 M0P11_2   M0P11_3 M0P11_4 M0P11_9  \
# 1365      Sí      No      No       NaN     NaN  Menciona     NaN     NaN
# 8799      Sí      Sí      No  Menciona     NaN       NaN     NaN     NaN
# 2619      No      No      No       NaN     NaN  Menciona     NaN     NaN
#
#      M0P12 M0P12A M0P13 M0P13A     M0P14        M0P14A M0P15  \
# 1365    No   N.P.  N.P.   N.P.   Ninguna          N.P.  N.P.
# 8799    No   N.P.  N.P.   N.P.  1 pareja  Solo hombres    No
# 2619    No   N.P.  N.P.   N.P.  1 pareja  Solo hombres    Sí
#
#                                 M0P16   M0P17           M0P18 M1P1_0_1  \
# 1365                             N.P.    N.P.            N.P.     N.P.
# 8799                             N.P.    N.P.            N.P.     N.P.
# 2619  Sí, viven en el mismo domicilio  Casada  Más de 30 años    Nunca
#
#      M1P1_0_2 M1P1_0_3 M1P1_0_4 M1P1_0_5 M1P1_0_6 M1P1_0_7 M1P1_0_8 M1P1_0_9  \
# 1365     N.P.     N.P.     N.P.     N.P.     N.P.     N.P.     N.P.     N.P.
# 8799     N.P.     N.P.     N.P.     N.P.     N.P.     N.P.     N.P.     N.P.
# 2619    Nunca    Nunca    Nunca    Nunca    Nunca    Nunca    Nunca    Nunca
#
#      M1P1_0_10 M1P1_0_11 M1P1_A_1 M1P1_A_2 M1P1_A_3 M1P1_A_4 M1P1_A_5  ...  \
# 1365      N.P.      N.P.     N.P.     N.P.     N.P.     N.P.     N.P.  ...
# 8799      N.P.      N.P.     N.P.     N.P.     N.P.     N.P.     N.P.  ...
# 2619     Nunca     Nunca     N.P.     N.P.     N.P.     N.P.     N.P.  ...
#
#      SDE14                           SDE15      SDE16_3  \
# 1365    Sí                               3  No menciona
# 8799    No  0 No le tiene ninguna simpatía  No menciona
# 2619    No                               7  No menciona
#
#                               LUGAR VALORACION_1 VALORACION_2 VALORACION_3  \
# 1365  En el interior de la vivienda  No menciona  No menciona  No menciona
# 8799  En el interior de la vivienda  No menciona     Menciona     Menciona
# 2619    En la puerta de la vivienda  No menciona  No menciona  No menciona
#
#      VALORACION_4 INTERVENCION INTERVENCION_A_1 INTERVENCION_A_2  \
# 1365     Menciona           No             N.P.             N.P.
# 8799  No menciona           Sí              NaN              NaN
# 2619     Menciona           No             N.P.             N.P.
#
#      INTERVENCION_A_3 INTERVENCION_A_4 INTERVENCION_A_5 INTERVENCION_A_6  \
# 1365             N.P.             N.P.             N.P.             N.P.
# 8799              NaN              NaN         Menciona              NaN
# 2619             N.P.             N.P.             N.P.             N.P.
#
#      INTERVENCION_A_7 INTERVENCION_A_8 INTERVENCION_A_9  \
# 1365             N.P.             N.P.             N.P.
# 8799              NaN              NaN              NaN
# 2619             N.P.             N.P.             N.P.
#
#                                         TARJETAS   OCULTACION ESTUDIOSPAR  \
# 1365  La persona entrevistada las ha usado todas  Creo que no        N.P.
# 8799                             Las he leído yo  Creo que no        N.P.
# 2619  La persona entrevistada las ha usado todas  Creo que no    Primaria
#
#           ESTUDIOS                                                OCUMAR11  \
# 1365    Superiores    Técnicas y profesionales científicas e intelectuales
# 8799  Sin estudios                                                     NaN
# 2619      Primaria  Operadoras de instalaciones y maquinaria, y montadoras
#
#          RAMA09                                                       OCUPAPP  \
# 1365  Servicios  Trabajadores/as cualificados/as en el sector agrícola, ganad
# 8799        NaN                                                           NaN
# 2619  Industria  Artesanos/as y trabajadores/as cuali. de ind. manufactureras
#
#            RAMAPP     PESO      SITULAB M1P2 M5P1F_9 M5P1F_10 M5P1F_11  \
# 1365  Agricultura   .58297  NO OCUPADAS    0    N.P.     N.P.     N.P.
# 8799          NaN  1.79213  NO OCUPADAS    0    N.P.     N.P.     N.P.
# 2619    Servicios  1.86687  NO OCUPADAS    0    N.P.     N.P.     N.P.
#
#      M5P1F_12 M5P1F_13 M5P1F_14 M5P1F_99 M5P1G_1 M5P1G_2 M5P1G_3 M5P1G_4  \
# 1365     N.P.     N.P.     N.P.     N.P.    N.P.    N.P.    N.P.    N.P.
# 8799     N.P.     N.P.     N.P.     N.P.    N.P.    N.P.    N.P.    N.P.
# 2619     N.P.     N.P.     N.P.     N.P.    N.P.    N.P.    N.P.    N.P.
#
#      M5P1G_9 SDE1                      SDE2    SDE3                     SDE4  \
# 1365    N.P.   23  La nacionalidad española  España  Sí, ha ido a la escuela
# 8799    N.P.   83  La nacionalidad española  España      No, es analfabeto/a
# 2619    N.P.   72  La nacionalidad española  España  Sí, ha ido a la escuela
#
#                                                              SDE4A ESTUDIOSP  \
# 1365  Diplomado/a, Grado (Bolonia), Ingeniero/a o Arquitecto/a Téc      N.C.
# 8799                                                           NaN      N.C.
# 2619  Antigua Educación Primaria (Certificado de Estudios Primario  Primaria
#
#      SDE5A_1 SDE5A_2  \
# 1365       0       3
# 8799     NaN     NaN
# 2619      30       0
#
#                                                               SDE7  \
# 1365  Asalariado/a eventual o interino/a (a sueldo, comisión, jorn
# 8799                                                           NaN
# 2619  Asalariado/a fijo/a (a sueldo, comisión, jornal, etc. con ca
#
#                                       SDE8  \
# 1365  Salario del trabajo por cuenta ajena
# 8799                   Pensión de viudedad
# 2619  No tengo ingresos (otros) personales
#
#                                      SDE8A                     SDE9  \
# 1365  No tengo ingresos (otros) personales             Otra persona
# 8799  No tengo ingresos (otros) personales  La persona entrevistada
# 2619                                   NaN             Otra persona
#
#                                         SDE9A  \
# 1365  Esa persona es su padre/madre, suegro/a
# 8799                                      NaN
# 2619       Esa persona es su cónyuge o pareja
#
#                                                     SDE9B  \
# 1365  Jubilada o pensionista (anteriormente ha trabajado)
# 8799                                                  NaN
# 2619  Jubilada o pensionista (anteriormente ha trabajado)
#
#                                                              SDE9D  \
# 1365                 Empresario/a o profesional con asalariados/as
# 8799                                                           NaN
# 2619  Asalariado/a fijo/a (a sueldo, comisión, jornal, etc. con ca
#
#                      SDE10  SDE10A_1 SDE10A_2  SDE10A_3 SDE10A_4 SDE10A_5  \
# 1365                     4       NaN      NaN  Menciona      NaN      NaN
# 8799  1 persona, vive sola      N.P.     N.P.      N.P.     N.P.     N.P.
# 2619            2 personas  Menciona      NaN       NaN      NaN      NaN
#
#      SDE10A_6  SDE10A_7 SDE10A_8 SDE10A_9 SDE10A_10 SDE10A_11 SDE10A_12  \
# 1365      NaN  Menciona      NaN      NaN       NaN       NaN       NaN
# 8799     N.P.      N.P.     N.P.     N.P.      N.P.      N.P.      N.P.
# 2619      NaN       NaN      NaN      NaN       NaN       NaN       NaN
#
#      SDE10A_13 SDE10A_99                  SDE11      SDE16_1      SDE16_2  \
# 1365       NaN       NaN  De 901 a 1.200 &euro;  No menciona     Menciona
# 8799      N.P.      N.P.  De 901 a 1.200 &euro;     Menciona  No menciona
# 2619       NaN       NaN         (NO LEER) N.C.     Menciona  No menciona
#
#      PESOCCAA
# 1365   .99547
# 8799  1.01251
# 2619    .9829
#
# [3 rows x 1121 columns]

# %%
# podemos ver de que tipo son los features
data_types = dataset.dtypes
data_types = pd.DataFrame(data_types)
data_types = data_types.rename(columns = {0:'ReadingDataType'})
data_types.index.names = ['FieldName']
data_types
# Out:
#           ReadingDataType
# FieldName
# ESTUDIO            object
# REGISTRO           object
# CUES               object
# FECHAINI           object
# HORAINI            object
# ...                   ...
# SDE10A_99          object
# SDE11              object
# SDE16_1            object
# SDE16_2            object
# PESOCCAA           object
#
# [1121 rows x 1 columns]

# %% [markdown]
# ### Algunos ejemplos

# %% [markdown]
# Veamos algunas variables como ejemplo.
#
# Tomemos la pregunta M0P0 "Frecuencia con que se han sufrido diferentes comportamientos de la pareja actual: violencia psicológica (control social)". Esta es una pregunta de múltiple opción. Entonces las columnas que nos interesan son las que tienen por nombre:
#
# M1P1_0_1,M1P1_0_2,...,M1P1_0_11.

# %%
cols_M1P1 = [col for col in dataset.columns if 'M1P1_0_' in col]

# %% [markdown]
# Así podemos trabajar con un dataset más chico seleccionando estas columnas

# %%
dataset_M1P1 = dataset[cols_M1P1]
display(dataset_M1P1)
# Out:
#      M1P1_0_1 M1P1_0_2       M1P1_0_3 M1P1_0_4 M1P1_0_5 M1P1_0_6 M1P1_0_7  \
# 0       Nunca    Nunca          Nunca    Nunca    Nunca    Nunca    Nunca
# 1       Nunca    Nunca          Nunca    Nunca    Nunca    Nunca    Nunca
# 2       Nunca    Nunca          Nunca    Nunca    Nunca    Nunca    Nunca
# 3       Nunca    Nunca          Nunca    Nunca    Nunca    Nunca    Nunca
# 4       Nunca    Nunca          Nunca    Nunca    Nunca    Nunca    Nunca
# ...       ...      ...            ...      ...      ...      ...      ...
# 9563    Nunca    Nunca          Nunca    Nunca    Nunca    Nunca    Nunca
# 9564    Nunca    Nunca  Algunas veces    Nunca    Nunca    Nunca    Nunca
# 9565    Nunca    Nunca          Nunca    Nunca    Nunca    Nunca    Nunca
# 9566    Nunca    Nunca          Nunca    Nunca    Nunca    Nunca    Nunca
# 9567    Nunca    Nunca          Nunca    Nunca    Nunca    Nunca    Nunca
#
#      M1P1_0_8 M1P1_0_9 M1P1_0_10 M1P1_0_11
# 0       Nunca    Nunca     Nunca     Nunca
# 1       Nunca    Nunca     Nunca     Nunca
# 2       Nunca    Nunca     Nunca     Nunca
# 3       Nunca    Nunca     Nunca     Nunca
# 4       Nunca    Nunca     Nunca     Nunca
# ...       ...      ...       ...       ...
# 9563    Nunca    Nunca     Nunca     Nunca
# 9564    Nunca    Nunca     Nunca     Nunca
# 9565    Nunca    Nunca     Nunca     Nunca
# 9566    Nunca    Nunca     Nunca     Nunca
# 9567    Nunca    Nunca     Nunca     Nunca
#
# [9568 rows x 11 columns]

# %% [markdown]
# De aquí, un primer análisis que podemos hacer es contar la cantidad de respuestas

# %%
ans_M1P1 = dataset_M1P1.apply(pd.Series.value_counts, axis=0)
ans_M1P1
# Out:
#                 M1P1_0_1  M1P1_0_2  M1P1_0_3  M1P1_0_4  M1P1_0_5  M1P1_0_6  \
# Algunas veces        130        67       214       217       228       165
# Frecuentemente        35        21        89        67        63        39
# N.C.                   6         5         4         6         6         7
# N.P.                3005      3005      3005      3005      3005      3005
# Nunca               6392      6470      6256      6273      6266      6352
#
#                 M1P1_0_7  M1P1_0_8  M1P1_0_9  M1P1_0_10  M1P1_0_11
# Algunas veces         87        65        87         42         27
# Frecuentemente        54        26        34         30         11
# N.C.                   7        30        30          7         29
# N.P.                3005      3005      3005       3005       3005
# Nunca               6415      6442      6412       6484       6496

# %%
column_dict =  {'SDE1': 'edad',
                'M0P0': 'sit_laboral',
                'M0P2': 'contencion_emocional',
                'M0P3': 'contencion_fisica',
                'M0P4': 'tiene_hijos',
                'M0P4A': 'hijo_menor18',
                'M0P4B': 'n_hijos_menor18',
                'M0P4C': 'n_hijos_menor_conviven',
                'M0P8': 'discapacidad',
                'M0P9': 'impedimento_laboral',
                'M0P15': 'tiene_pareja',
                'M0P16': 'convive_pareja_actual',
                'M0P17': 'sit_legal_pareja_actual',
                'M0P18': 'tiempo_pareja_actual',
                'M1P1_0_2': 'vpsico_ver_familia',
                'M1P1_0_8': 'vpsico_dar_dinero',
                'M1P1_0_9': 'vpsico_eco_familiar',
                'M1P1_0_10': 'vpsico_trabajar_estudiar',
                'M1P1_0_11': 'vpsico_usa_tu_dinero',
                'M1P3C': 'vpsico_reiterada',
                'M1P3D': 'frecuencia_vpisco',
                'M1P11': 'absentismo_laboral_violencia',
                'M5P1_5': 'dano_propiedad_reiterado',
                'SDE5': 'trabajo_remunerado_algunavez', 
                'SDE5A': 'fin_ultimo_trabajo' , 
                'SDE8': 'fuente_ingresos_ppal' , 
                'SDE8A': 'fuente_ingresos_alt', 
                'SDE9': 'mayor_ingreso_hogar',
                'SDE10': 'tamano_hogar',  #cantidad de personas en el hogar
                'ESTUDIOSP': 'estudios_max',
                'OCUMAR11': 'ocupacion'
                }

# %%
dataset_veconomica = dataset.rename(columns=column_dict)[[*column_dict.values()]]

# %%
df_vecon1 = dataset_veconomica.replace({"sit_laboral": {'Trabaja': "Trabaja",
                                           'Trabaja o colabora de manera habitual en el negocio familiar': "Trabaja",
                                           'Jubilada o pensionista (anteriormente ha trabajado)': "No_trabaja",
                                           'Pensionista (anteriormente no ha trabajado)': "No_trabaja",
                                           'Parada y ha trabajado antes': "No_trabaja",
                                           'Parada y busca su primer empleo': "No_trabaja",
                                           'Estudiante': "No_trabaja",
                                           'Trabajo doméstico no remunerado': "No_trabaja",
                                           'Otra situación': "No_trabaja"}})

# %% [markdown]
# ###Análisis sobre las edades de las personas encuestadas

# %%
plt.subplots(figsize=(20,8))

sns.histplot(df_vecon1['edad'].sort_values(), bins=10, discrete=True)
plt.title("Edad de las personas encuestadas")
plt.xticks(rotation=90, fontsize=10)
plt.xlabel("Edad", fontsize=14)
# Out:
# Text(0.5, 0, 'Edad')

# %%
df_vecon1['tiene_pareja'].value_counts()
# Out:
# Sí      6563
# No      2628
# N.P.     370
# N.C.       7
# Name: tiene_pareja, dtype: int64

# %% [markdown]
# Visualizamos las personas que tienen pareja y su distribución de edad. Podemos ver que las personas encuestadas entre 16 y 25 años en el gráfico de personas que tienen pareja, están representadas en un porcentaje menor.

# %%
df_vecon_pareja = df_vecon1[df_vecon1['tiene_pareja'].str.contains('Sí')]

# %%
plt.subplots(figsize=(20,8))

sns.histplot(df_vecon_pareja['edad'].sort_values(), bins=10, discrete=True)
plt.title("Edad de las personas encuestadas")
plt.xticks(rotation=90, fontsize=10)
plt.xlabel("Edad", fontsize=14)
# Out:
# Text(0.5, 0, 'Edad')

# %%
df_vecon1.sit_laboral.value_counts()
# Out:
# No_trabaja    5362
# Trabaja       4206
# Name: sit_laboral, dtype: int64

# %% [markdown]
# ### Análisis de la distribución de la edad

# %%
df_vecon1['edad'].describe()
# Out:
# count     9568
# unique      81
# top         45
# freq       228
# Name: edad, dtype: object

# %%
df_vecon1[['edad']] = df_vecon1[['edad']].apply(pd.to_numeric)
# antes de esta transformación el tipo de dato en esta columna era 'objet',
# después de la transformación  el tipo de dato es float64

# %%
df_vecon1['edad'].describe()
# Out:
# count    9568.000000
# mean       49.956940
# std        18.350114
# min        16.000000
# 25%        36.000000
# 50%        49.000000
# 75%        64.000000
# max        96.000000
# Name: edad, dtype: float64

# %%
plt.figure(figsize=(7,5))

sns.histplot(df_vecon1['edad'], bins=50, color='silver')
plt.title('Distribución de la edad', fontsize=15)
plt.xlabel('Edad', fontsize =14)
plt.ylabel('Conteo', fontsize=14)
#plt.legend(fontsize = 12)
plt.show()

# %%
df_vecon1 = df_vecon1.replace({"mayor_ingreso_hogar": {
    "(NO LEER) La persona entrevistada y otra casi a partes igual":
     "La mitad la entrevistada"}}
     )

# %%
plt.figure(figsize=(7,5))

sns.boxplot(data = df_vecon1, x='edad', y='mayor_ingreso_hogar')
plt.ylabel('Ingreso principal del hogar', fontsize = 14)
plt.xlabel('Edad', fontsize = 14)
plt.yticks(rotation=30, size=12)
plt.xticks(size=12)
plt.ticklabel_format(style='plain', axis='x')
plt.show()

# %%
orden_estudio = ['Sin estudios', 'Primaria', 'Secundaria 1ª etapa', 
                 'Secundaria 2ª etapa', 'F.P', 'Superiores', 'Otros', 'N.S.', 'N.C.']

# %%
plt.figure(figsize=(7,5))

sns.boxplot(data = df_vecon1, x='edad', y='estudios_max', order =orden_estudio)
plt.ylabel('Estudio máximo', fontsize = 14)
plt.xlabel('Edad', fontsize = 14)
plt.yticks(rotation=30, size=12)
plt.xticks(size=12)
plt.ticklabel_format(style='plain', axis='x')
plt.show()

# %%
df_vecon1[['mayor_ingreso_hogar']].value_counts()
# Out:
# mayor_ingreso_hogar
# Otra persona                4820
# La persona entrevistada     3271
# La mitad la entrevistada    1413
# N.C.                          64
# dtype: int64

# %%
df_edad_ingreso = df_vecon1.groupby('mayor_ingreso_hogar').describe().edad

df_edad_ingreso.sort_values('mean', ascending =False)
# Out:
#                            count       mean        std   min    25%   50%  \
# mayor_ingreso_hogar
# La persona entrevistada   3271.0  56.258942  17.605529  16.0  42.00  56.0
# N.C.                        64.0  48.765625  18.309285  20.0  32.75  48.0
# La mitad la entrevistada  1413.0  48.443029  14.552549  16.0  37.00  47.0
# Otra persona              4820.0  46.139834  18.695237  16.0  30.00  45.0
#
#                             75%   max
# mayor_ingreso_hogar
# La persona entrevistada   70.00  96.0
# N.C.                      64.25  85.0
# La mitad la entrevistada  59.00  91.0
# Otra persona              61.00  95.0

# %% [markdown]
# A partir de esto, parece haber ocasiones donde la persona entravistada, que tiene 16 años, es la persona que aporta el ingreso principal al hogar. También parece que hay casos en los cuales la persona tiene 16 años, pero aporta de manera casi igual que otra de las personas

# %%
ing_ppal_otro = df_vecon1[df_vecon1['mayor_ingreso_hogar']=='Otra persona']
ing_ppal_otro['estudios_max'].value_counts()
# Out:
# Secundaria 1ª etapa    975
# N.C.                   892
# Superiores             784
# Primaria               783
# F.P.                   739
# Secundaria 2ª etapa    510
# Sin estudios            98
# N.S.                    38
# Otros                    1
# Name: estudios_max, dtype: int64

# %%
plt.figure(figsize=(7,5))

sns.boxplot(data = ing_ppal_otro, x='edad', y='estudios_max', order=orden_estudio)
plt.title('Estudios de las personas donde el ingreso ppal es otra persona', fontsize=15)
plt.ylabel('Estudios de la persona', fontsize = 14)
plt.xlabel('Edad', fontsize = 14)
plt.yticks(rotation=30, size=12)
plt.xticks(size=12)
plt.ticklabel_format(style='plain', axis='x')
plt.show()

# %% [markdown]
# Parecería que para las personas con una edad media mayor a 60 años, que no tienen estudios máás allá del primario la otra persona es la fuente principal de ingresos de la casa. Pero sin embargo, en el gráfico previo donde se ve como se distribuye toda la población, parece ser que simplemente para las personas mayores a 60 años, los estudios fueron ninguno o primaria solamente.

# %%
ing_ppal_ella = df_vecon1[df_vecon1['mayor_ingreso_hogar']=='La persona entrevistada']
ing_ppal_ella['estudios_max'].value_counts()
# Out:
# N.C.                   2157
# Superiores              285
# Secundaria 1ª etapa     248
# F.P.                    229
# Secundaria 2ª etapa     174
# Primaria                144
# N.S.                     22
# Sin estudios             11
# Otros                     1
# Name: estudios_max, dtype: int64

# %%
plt.figure(figsize=(7,5))

sns.boxplot(data = ing_ppal_ella, x='edad', y='estudios_max', order=orden_estudio)
plt.title('Estudios de las personas donde el ingreso ppal es ella', fontsize=15)
plt.ylabel('Estudios de la persona', fontsize = 14)
plt.xlabel('Edad', fontsize = 14)
plt.yticks(rotation=30, size=12)
plt.xticks(size=12)
plt.ticklabel_format(style='plain', axis='x')
plt.show()

# %% [markdown]
# Para este caso, donde la persona es el ingreso principal, la media de la edad de las personas sin estudios es menor, tambiéén la media de las personas que solo tienen de estudio la primaria.

# %%
ing_ppella_nc = ing_ppal_ella[ing_ppal_ella['estudios_max']=='N.C.']

# %%
plt.figure(figsize=(7,5))

sns.countplot(ing_ppella_nc.ocupacion)
plt.title('Ocupación de las mujeres que son el ingreso principal y tenian seleccionada como estudio N.C.', fontsize=15)
plt.ylabel('Conteo', fontsize = 14)
plt.xlabel('Ocupacion', fontsize = 14)
plt.yticks(size=12)
plt.xticks(rotation = 90, size=12)
#plt.ticklabel_format(style='plain', axis='x')
plt.show()

# %% [markdown]
# ### Visualizaciones sobre fuentes de ingresos principal

# %%
plt.subplots(figsize=(10,6))
plt.title("Fuente de ingresos principal")
sns.countplot(x="fuente_ingresos_ppal",  data=df_vecon_pareja)
plt.xticks(rotation=90, fontsize=14)
plt.xlabel("fuente_ingresos_ppal", fontsize=14)
# Out:
# Text(0.5, 0, 'fuente_ingresos_ppal')

# %%
df_vecon_filtrado = df_vecon1[df_vecon1['fuente_ingresos_ppal'].isin(['No tengo ingresos (otros) personales', 'Ayuda/asignación de pareja', 'Ayuda/asignación de la expareja'])]

# %%
plt.subplots(figsize=(10,6))
plt.title("")
sns.countplot(x="vpsico_dar_dinero", hue="vpsico_dar_dinero",  data=df_vecon_filtrado, alpha=0.5)

plt.xticks(rotation=90, fontsize=14)
plt.xlabel("vpsico_dar_dinero", fontsize=14)
# Out:
# Text(0.5, 0, 'vpsico_dar_dinero')

# %% [markdown]
# ### Reducción de categorías para la variable fuente de ingresos propios

# %%
df_vecon1.fuente_ingresos_ppal.value_counts()
# Out:
# Salario del trabajo por cuenta ajena                   3565
# No tengo ingresos (otros) personales                   2170
# Pensión de jubilación                                  1334
# Salario del trabajo por cuenta propia                   639
# Pensión de viudedad                                     555
# Prestación de desempleo                                 385
# Subsidio (ayudas sociales)                              252
# Ayuda/asignación de pareja                              168
# Ayuda/asignación de su padre/madre                      150
# Otro no contemplado anteriormente                        86
# Pensión compensatoria                                    63
# Rentas, ahorro (viviendas, tierras, acciones, etc.)      63
# N.C.                                                     51
# Beca                                                     38
# Ayuda/asignación de la expareja                          27
# Ayuda/asignación de otra persona                         22
# Name: fuente_ingresos_ppal, dtype: int64

# %%
df_vecon2 = df_vecon1.replace({"fuente_ingresos_ppal": {"Ayuda/asignación de la expareja": "No",
                                                           "Ayuda/asignación de otra persona": "No",
                                                           "Ayuda/asignación de pareja": "No",
                                                           "Ayuda/asignación de su padre/madre": "No",
                                                           "Beca": "Si",
                                                           "N.C.": "No",
                                                           "No tengo ingresos (otros) personales": "No",
                                                           "Otro no contemplado anteriormente": "Si",
                                                           "Pensión compensatoria": "Si",
                                                           "Pensión de jubilación": "Si",
                                                           "Pensión de viudedad": "Si",
                                                           "Prestación de desempleo": "Si",
                                                           "Rentas, ahorro (viviendas, tierras, acciones, etc.)": "Si",
                                                           "Salario del trabajo por cuenta ajena": "Si",
                                                           "Salario del trabajo por cuenta propia": "Si",
                                                           "Subsidio (ayudas sociales)": "Si"}})

# %%
df_vecon2.fuente_ingresos_ppal.unique()
# Out:
# array(['No', 'Si'], dtype=object)

# %%
df_vecon2.fuente_ingresos_alt.value_counts()
# Out:
# No tengo ingresos (otros) personales                   5609
# Ayuda/asignación de pareja                              325
# Pensión de viudedad                                     254
# Rentas, ahorro (viviendas, tierras, acciones, etc.)     239
# N.C.                                                    232
# Otro no contemplado anteriormente                       228
# Ayuda/asignación de su padre/madre                       81
# Salario del trabajo por cuenta ajena                     68
# Salario del trabajo por cuenta propia                    65
# Ayuda/asignación de la expareja                          64
# Subsidio (ayudas sociales)                               64
# Pensión de jubilación                                    61
# Ayuda/asignación de otra persona                         42
# Beca                                                     28
# Pensión compensatoria                                    24
# Prestación de desempleo                                  14
# Name: fuente_ingresos_alt, dtype: int64

# %%
df_vecon2.fuente_ingresos_alt.isnull()
# Out:
# 0        True
# 1       False
# 2        True
# 3        True
# 4        True
#         ...
# 9563    False
# 9564    False
# 9565    False
# 9566    False
# 9567    False
# Name: fuente_ingresos_alt, Length: 9568, dtype: bool

# %%
df_vecon3 = df_vecon2.replace({"fuente_ingresos_alt": {"No tengo ingresos (otros) personales": "No",
                                                                "Ayuda/asignación de pareja": "No",
                                                                "Pensión de viudedad": "Si",
                                                                "Rentas, ahorro (viviendas, tierras, acciones, etc.)": "Si",
                                                                "N.C.": "N.C.",
                                                                "Otro no contemplado anteriormente": "Si",
                                                                "Ayuda/asignación de su padre/madre": "No",
                                                                "Salario del trabajo por cuenta ajena": "Si",
                                                                "Salario del trabajo por cuenta propia": "Si",
                                                                "Ayuda/asignación de la expareja": "No",
                                                                "Subsidio (ayudas sociales)": "Si",
                                                                "Pensión de jubilación": "Si",
                                                                "Ayuda/asignación de otra persona": "No",
                                                                "Beca": "Si",
                                                                "Pensión compensatoria": "Si",
                                                                "Prestación de desempleo": "Si"}})

# %%
df_vecon3.fuente_ingresos_alt[:15]
# Out:
# 0     NaN
# 1      No
# 2     NaN
# 3     NaN
# 4     NaN
# 5      No
# 6     NaN
# 7      No
# 8      No
# 9      No
# 10    NaN
# 11     No
# 12     No
# 13     No
# 14    NaN
# Name: fuente_ingresos_alt, dtype: object

# %%
df_vecon3.fuente_ingresos_alt.isnull()
# Out:
# 0        True
# 1       False
# 2        True
# 3        True
# 4        True
#         ...
# 9563    False
# 9564    False
# 9565    False
# 9566    False
# 9567    False
# Name: fuente_ingresos_alt, Length: 9568, dtype: bool

# %%
df_vecon3.fuente_ingresos_alt.fillna("No", inplace=True)

# %%
df_vecon3.fuente_ingresos_alt.isna().value_counts()
# Out:
# False    9568
# Name: fuente_ingresos_alt, dtype: int64

# %%
df_vecon_pareja = df_vecon3[df_vecon3['tiene_pareja'].str.contains('Sí')]

# %%
df_vecon_pareja_cat = df_vecon3[df_vecon3['tiene_pareja'].str.contains('Sí')]

# %%
import pandas as pd
pd.crosstab(index=df_vecon_pareja['fuente_ingresos_ppal'],
            columns=df_vecon_pareja['sit_laboral'], margins=True).apply(lambda r: r/len(df_vecon_pareja) *100, axis=True)
# Out:
# sit_laboral           No_trabaja    Trabaja         All
# fuente_ingresos_ppal
# No                     29.026360   1.904617   30.930977
# Si                     22.032607  47.036416   69.069023
# All                    51.058967  48.941033  100.000000

# %% [markdown]
# En esta tabla de contingencia, vemos que cerca de un 70% tiene una fuente principal de ingresos propios, mientras que un 30% no. Sin embargo, solamente el 50% trabaja y otro 50% no trabaja. Es decir, que el trabajo es una fuente muy importante, pero no la única, de los ingresos personales. Otras fuentes (ese 20% restante) está compuesto por: pensiones, jubilaciones, becas, subsidios o ahorros y rentas a la propiedad.
# En este caso podríamos decir que fuente de ingresos y situación laboral no me están dando exactamente la misma información, por lo que no podríamos descartar ninguna de estas preguntas. Sí, por el contrario, podríamos reducir la cantidad de respuestas posibles.

# %% [markdown]
# ###Correlacion

# %%
import seaborn

plt.figure(figsize=(8,6))
exp = pd.crosstab(df_vecon_pareja.sit_laboral,
                  df_vecon_pareja.fuente_ingresos_ppal)
seaborn.heatmap(exp, annot=True, fmt="g")

# %%
pd.crosstab(df_vecon_pareja.fuente_ingresos_ppal, df_vecon_pareja.fuente_ingresos_alt, margins=True, normalize=True)
# Out:
# fuente_ingresos_alt       N.C.        No        Si      All
# fuente_ingresos_ppal
# No                    0.000457  0.297577  0.011275  0.30931
# Si                    0.023770  0.600945  0.065976  0.69069
# All                   0.024227  0.898522  0.077251  1.00000

# %% [markdown]
# En cuanto a los ingresos alternativos, solo 8% afirma poseerlos. De ese total, un 7% cuenta, además, con ingresos propios como fuente principal de dinero. Sólo un 1% de las personas que no cuentan con ingresos propios como fuente principal, cuentan únicamente con ingresos alternativos.

# %%
pd.crosstab([df_vecon_pareja.fuente_ingresos_ppal, df_vecon_pareja.fuente_ingresos_alt], df_vecon_pareja.sit_laboral,
            rownames=["fuente_ingresos_ppal", "fuente_ingresos_alt"], colnames=["sit_laboral"], margins=True).apply(lambda r: r/len(df_vecon_pareja)* 100, axis=True)
# Out:
# sit_laboral                               No_trabaja    Trabaja         All
# fuente_ingresos_ppal fuente_ingresos_alt
# No                   N.C.                   0.045711   0.000000    0.045711
#                      No                    28.249276   1.508456   29.757733
#                      Si                     0.731373   0.396160    1.127533
# Si                   N.C.                   0.746610   1.630352    2.376962
#                      No                    19.107116  40.987353   60.094469
#                      Si                     2.178882   4.418711    6.597593
# All                                        51.058967  48.941033  100.000000

# %% [markdown]
# Acá podemos ver las dos variables de ingresos (principal y alternativa) en relación a la tenencia de un trabajo. Nuevamente, la mitad de las personas encuestadas trabaja y la otra mitad no. Las personas con ingresos principales y alternativos solo suma un 7%. En cambio, un 60% cuenta únicamente con ingresos principales. Un 9% cuenta únicamente con ingresos alternativos (6% no trabaja y 3% sí). Las personas que no cuentan ni con ingresos principales ni con alternativos, ascienden a cerca de 30%.

# %%
df_vpsico = df_vecon_pareja[['vpsico_dar_dinero', 'vpsico_eco_familiar', 'vpsico_trabajar_estudiar', 'vpsico_usa_tu_dinero', 'vpsico_ver_familia']]
df_vpsico.apply(pd.Series.value_counts, axis=0)
# Out:
#                 vpsico_dar_dinero  vpsico_eco_familiar  \
# Algunas veces                  65                   87
# Frecuentemente                 26                   34
# N.C.                           30                   30
# Nunca                        6442                 6412
#
#                 vpsico_trabajar_estudiar  vpsico_usa_tu_dinero  \
# Algunas veces                         42                    27
# Frecuentemente                        30                    11
# N.C.                                   7                    29
# Nunca                               6484                  6496
#
#                 vpsico_ver_familia
# Algunas veces                   67
# Frecuentemente                  21
# N.C.                             5
# Nunca                         6470

# %% [markdown]
# El 98% de nuestro universo muestral nunca ha recibido lo que consideramos violencia economica, y puede que esto tenga que ver con que casi el 70% cuenta con ingresos personales (principales, alternativos o ambos): un 50% provenientes de una fuente de trabajo y un 20% restante proveniente de pensiones, jubilación, subsidios, becas, rentas.

# %%
df_vecon_pareja.vpsico_dar_dinero = df_vecon_pareja.vpsico_dar_dinero.replace("Frecuentemente", 1).replace("Algunas veces", 1).replace("Nunca", 0).replace("N.C.", 0)
df_vecon_pareja.vpsico_eco_familiar = df_vecon_pareja.vpsico_eco_familiar.replace("Frecuentemente", 1).replace("Algunas veces", 1).replace("Nunca", 0).replace("N.C.", 0)
df_vecon_pareja.vpsico_trabajar_estudiar = df_vecon_pareja.vpsico_trabajar_estudiar.replace("Frecuentemente", 1).replace("Algunas veces", 1).replace("Nunca", 0).replace("N.C.", 0)
df_vecon_pareja.vpsico_usa_tu_dinero = df_vecon_pareja.vpsico_usa_tu_dinero.replace("Frecuentemente", 1).replace("Algunas veces", 1).replace("Nunca", 0).replace("N.C.", 0)
df_vecon_pareja.sit_laboral = df_vecon_pareja.sit_laboral.replace("Trabaja", 1).replace("No_trabaja", 0)
df_vecon_pareja.fuente_ingresos_alt = df_vecon_pareja.fuente_ingresos_alt.replace("No", 0).replace("Si", 1).replace("N.C.", 0)
df_vecon_pareja.fuente_ingresos_ppal = df_vecon_pareja.fuente_ingresos_ppal.replace("No", 0).replace("Si", 1).replace("N.C.", 0)

# %%
df_vecon_pareja.fuente_ingresos_alt.value_counts()
# Out:
# 0    6056
# 1     507
# Name: fuente_ingresos_alt, dtype: int64

# %%
df_vecon_pareja.head()
# Out:
#    edad  sit_laboral contencion_emocional contencion_fisica tiene_hijos  \
# 0    53            0                   Sí                Sí          Sí
# 1    55            1                   Sí                Sí          Sí
# 2    68            0                   No                No          Sí
# 3    50            0                   No                Sí          Sí
# 4    68            0                   Sí                Sí          Sí
#
#   hijo_menor18 n_hijos_menor18 n_hijos_menor_conviven discapacidad  \
# 0           No            N.P.                   N.P.           No
# 1           No            N.P.                   N.P.           No
# 2           No            N.P.                   N.P.           No
# 3           No            N.P.                   N.P.           No
# 4           No            N.P.                   N.P.           No
#
#                 impedimento_laboral tiene_pareja  \
# 0                                No           Sí
# 1                                No           Sí
# 2        Sí, y le limita gravemente           Sí
# 3                                No           Sí
# 4  Sí, pero no le limita gravemente           Sí
#
#              convive_pareja_actual sit_legal_pareja_actual  \
# 0  Sí, viven en el mismo domicilio                  Casada
# 1  Sí, viven en el mismo domicilio                  Casada
# 2  Sí, viven en el mismo domicilio                  Casada
# 3  Sí, viven en el mismo domicilio                  Casada
# 4  Sí, viven en el mismo domicilio                  Casada
#
#   tiempo_pareja_actual vpsico_ver_familia  vpsico_dar_dinero  \
# 0   Entre 21 y 30 años              Nunca                  0
# 1       Más de 30 años              Nunca                  0
# 2       Más de 30 años              Nunca                  0
# 3   Entre 21 y 30 años              Nunca                  0
# 4       Más de 30 años              Nunca                  0
#
#    vpsico_eco_familiar  vpsico_trabajar_estudiar  vpsico_usa_tu_dinero  \
# 0                    0                         0                     0
# 1                    0                         0                     0
# 2                    0                         0                     0
# 3                    0                         0                     0
# 4                    0                         0                     0
#
#   vpsico_reiterada frecuencia_vpisco absentismo_laboral_violencia  \
# 0             N.P.              N.P.                         N.P.
# 1             N.P.              N.P.                         N.P.
# 2             N.P.              N.P.                         N.P.
# 3             N.P.              N.P.                         N.P.
# 4             N.P.              N.P.                         N.P.
#
#   dano_propiedad_reiterado trabajo_remunerado_algunavez fin_ultimo_trabajo  \
# 0                       No            Sí, anteriormente                 20
# 1                       No          Sí en la actualidad                NaN
# 2                       No            Sí, anteriormente                 36
# 3                       No            Sí, anteriormente                 49
# 4                       No            Sí, anteriormente                 46
#
#    fuente_ingresos_ppal  fuente_ingresos_alt mayor_ingreso_hogar tamano_hogar  \
# 0                     0                    0        Otra persona   3 personas
# 1                     1                    0        Otra persona   3 personas
# 2                     0                    0        Otra persona   2 personas
# 3                     0                    0        Otra persona            4
# 4                     0                    0        Otra persona   2 personas
#
#           estudios_max  \
# 0             Primaria
# 1  Secundaria 1ª etapa
# 2             Primaria
# 3                 F.P.
# 4             Primaria
#
#                                                       ocupacion
# 0                                       Ocupaciones elementales
# 1  Trabajadoras de los servicios de restauración, personales, p
# 2                                       Ocupaciones elementales
# 3                              Técnicas; profesionales de apoyo
# 4                                       Ocupaciones elementales

# %%
df_vecon_pareja["vpsico_dar_dinero"].value_counts()
# Out:
# 0    6472
# 1      91
# Name: vpsico_dar_dinero, dtype: int64

# %%
df_vecon_pareja.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6563 entries, 0 to 9567
# Data columns (total 31 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   edad                          6563 non-null   int64
#  1   sit_laboral                   6563 non-null   int64
#  2   contencion_emocional          6563 non-null   object
#  3   contencion_fisica             6563 non-null   object
#  4   tiene_hijos                   6563 non-null   object
#  5   hijo_menor18                  6563 non-null   object
#  6   n_hijos_menor18               6563 non-null   object
#  7   n_hijos_menor_conviven        6563 non-null   object
#  8   discapacidad                  6563 non-null   object
#  9   impedimento_laboral           6563 non-null   object
#  10  tiene_pareja                  6563 non-null   object
#  11  convive_pareja_actual         6563 non-null   object
#  12  sit_legal_pareja_actual       6563 non-null   object
#  13  tiempo_pareja_actual          6563 non-null   object
#  14  vpsico_ver_familia            6563 non-null   object
#  15  vpsico_dar_dinero             6563 non-null   int64
#  16  vpsico_eco_familiar           6563 non-null   int64
#  17  vpsico_trabajar_estudiar      6563 non-null   int64
#  18  vpsico_usa_tu_dinero          6563 non-null   int64
#  19  vpsico_reiterada              6563 non-null   object
#  20  frecuencia_vpisco             6563 non-null   object
#  21  absentismo_laboral_violencia  6563 non-null   object
#  22  dano_propiedad_reiterado      6563 non-null   object
#  23  trabajo_remunerado_algunavez  6563 non-null   object
#  24  fin_ultimo_trabajo            2458 non-null   object
#  25  fuente_ingresos_ppal          6563 non-null   int64
#  26  fuente_ingresos_alt           6563 non-null   int64
#  27  mayor_ingreso_hogar           6563 non-null   object
#  28  tamano_hogar                  6563 non-null   object
#  29  estudios_max                  6563 non-null   object
#  30  ocupacion                     5710 non-null   object
# dtypes: int64(8), object(23)
# memory usage: 1.6+ MB

# %%
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(10, 4))

axs[0].hist(x=df_vecon_pareja_cat.vpsico_eco_familiar, bins=3, color="gray", alpha=0.5)
axs[0].plot(df_vecon_pareja_cat.vpsico_eco_familiar, np.full_like(df_vecon_pareja_cat.vpsico_eco_familiar, -0.01), '|k', markeredgewidth=1)
axs[0].set_title('Involucramiento en economía del hogar')

axs[1].hist(x=df_vecon_pareja_cat.vpsico_dar_dinero, bins=3, color="gray", alpha=0.5)
axs[1].plot(df_vecon_pareja_cat.vpsico_dar_dinero, np.full_like(df_vecon_pareja_cat.vpsico_dar_dinero, -0.01), '|k', markeredgewidth=1)
axs[1].set_title('Recepción de dinero')

plt.tight_layout()

# %%
# Usamos el coeficiente Tau de Kendall que se usa cuando los datos son muy escasos y se acumulan dentro de un rango, como en nuestro caso

print('Correlación kendall: ', df_vecon_pareja['vpsico_eco_familiar'].corr(df_vecon_pareja['vpsico_dar_dinero'], method='kendall'))
# Out:
# Correlación kendall:  0.574615193259346

# %%
# Lo calculamos con otra librería que nos da la significancia
from scipy import stats
from scipy.stats import pearsonr
r, p = stats.kendalltau(df_vecon_pareja['vpsico_eco_familiar'], df_vecon_pareja['vpsico_dar_dinero'])
print(f"Correlación Kendall: r={r}, p-value={p}")
# Out:
# Correlación Kendall: r=0.574615193259346, p-value=0.0

# %% [markdown]
# ** Eureka! Si bien el coeficiente de Kendal no es del todo muy alto, me muestra una correlación moderada y positiva, con un valor p de cero.

# %%
r, p = stats.kendalltau(df_vecon_pareja['vpsico_eco_familiar'], df_vecon_pareja['vpsico_usa_tu_dinero'])
print(f"Correlación Kendall: r={r}, p-value={p}")
#Acá la correlación es tirando a baja, menos de 0.5
# Out:
# Correlación Kendall: r=0.25825485088675826, p-value=3.503684321958175e-97

# %%
r, p = stats.kendalltau(df_vecon_pareja['vpsico_eco_familiar'], df_vecon_pareja['vpsico_trabajar_estudiar'])
print(f"Correlación Kendall: r={r}, p-value={p}")
#Acá lo mismo, sigue siendo tirando a baja
# Out:
# Correlación Kendall: r=0.3443978646399227, p-value=2.7936942293214405e-171

# %%
r, p = stats.kendalltau(df_vecon_pareja['vpsico_dar_dinero'], df_vecon_pareja['vpsico_trabajar_estudiar'])
print(f"Correlación Kendall: r={r}, p-value={p}")
# Out:
# Correlación Kendall: r=0.3377778163574903, p-value=7.754915579423682e-165

# %%
r, p = stats.kendalltau(df_vecon_pareja['vpsico_usa_tu_dinero'], df_vecon_pareja['vpsico_dar_dinero'])
print(f"Correlación Kendall: r={r}, p-value={p}")
# Out:
# Correlación Kendall: r=0.23139189897292312, p-value=2.160074649724589e-78

# %%
#Mejor vamos a armar una matriz enorme de correlación de todos contra todos

corr = df_vecon_pareja.corr(method="kendall")
mask = np.triu(np.ones_like(corr, dtype=bool))

fig, ax = plt.subplots(figsize=(12, 9))

cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(corr, annot=True, annot_kws = {"size": 8}, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
ax.tick_params(labelsize = 10)
